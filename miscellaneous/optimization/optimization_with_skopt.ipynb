# %%
import numpy as np
from skopt import gp_minimize

def f(x):
    return (np.sin(5 * x[0]) * (1 - np.tanh(x[0] ** 2)) *
            np.random.randn() * 0.1)

res = gp_minimize(f, [(-2.0, 2.0)])
# Out:
# /Users/hbi16859/anaconda/envs/python36/lib/python3.6/site-packages/skopt/optimizer/optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/hbi16859/anaconda/envs/python36/lib/python3.6/site-packages/skopt/optimizer/optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/hbi16859/anaconda/envs/python36/lib/python3.6/site-packages/skopt/optimizer/optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# /Users/hbi16859/anaconda/envs/python36/lib/python3.6/site-packages/skopt/optimizer/optimizer.py:399: UserWarning: The objective has been evaluated at this point before.
#   warnings.warn("The objective has been evaluated "
# ...

# %%
res
# Out:
#           fun: -0.054454593594479184
#     func_vals: array([-3.04232066e-02, -4.34915052e-04,  1.85391192e-04,  4.66011810e-02,
#        -5.44545936e-02, -1.95664230e-03, -4.77319660e-02,  3.21127323e-02,
#        -2.56978968e-04,  5.18427561e-02, -2.63927701e-05,  7.06955670e-06,
#         4.47864290e-05, -2.49982621e-05,  1.18845343e-05,  5.79087228e-06,
#         5.55739779e-05,  1.02484426e-05, -2.60226354e-05,  7.91101430e-06,
#        -2.72708436e-06,  2.16002808e-05,  5.33640068e-05, -3.81689347e-05,
#        -1.74233484e-05,  5.27241643e-05, -5.85531708e-05, -2.31980318e-05,
#         9.56602253e-06, -3.99867294e-05,  4.05626210e-06, -7.63333287e-06,
#        -9.07108749e-06, -3.00831706e-05, -3.39686931e-05,  2.77873616e-05,
#        -3.15390547e-05,  8.51441730e-06, -3.29018234e-05,  1.08583792e-05,
#         5.55095648e-05, -1.36638933e-05, -1.35907135e-05,  2.84343486e-05,
#        -4.92298386e-05, -3.41897433e-06,  5.98210566e-05, -2.77664150e-05,
# ...

# %%
type(res)
# Out:
# scipy.optimize.optimize.OptimizeResult

# %%
res.values()
# Out:
# dict_values([[-0.05992167114467861], -0.054454593594479184, array([-3.04232066e-02, -4.34915052e-04,  1.85391192e-04,  4.66011810e-02,
#        -5.44545936e-02, -1.95664230e-03, -4.77319660e-02,  3.21127323e-02,
#        -2.56978968e-04,  5.18427561e-02, -2.63927701e-05,  7.06955670e-06,
#         4.47864290e-05, -2.49982621e-05,  1.18845343e-05,  5.79087228e-06,
#         5.55739779e-05,  1.02484426e-05, -2.60226354e-05,  7.91101430e-06,
#        -2.72708436e-06,  2.16002808e-05,  5.33640068e-05, -3.81689347e-05,
#        -1.74233484e-05,  5.27241643e-05, -5.85531708e-05, -2.31980318e-05,
#         9.56602253e-06, -3.99867294e-05,  4.05626210e-06, -7.63333287e-06,
#        -9.07108749e-06, -3.00831706e-05, -3.39686931e-05,  2.77873616e-05,
#        -3.15390547e-05,  8.51441730e-06, -3.29018234e-05,  1.08583792e-05,
#         5.55095648e-05, -1.36638933e-05, -1.35907135e-05,  2.84343486e-05,
#        -4.92298386e-05, -3.41897433e-06,  5.98210566e-05, -2.77664150e-05,
# ...
